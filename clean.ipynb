# %% [markdown]
# Clean the Census data

# %% [markdown]
# Problem Statement 1: (Keep the relevant data)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the census data
census_data_relevant = pd.read_csv(r"Data\census_2011.csv")

# %%
census_data_relevant
# Out:
#      District code                   State name              District Name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
# Select the relevant columns
census_data_relevant = census_data_relevant[["State name", "District Name", "Population", "Male", "Female", "Literate", "Male_Literate", "Female_Literate", "Rural_Households", "Urban_Households", "Households","Age_Group_0_29", "Age_Group_30_49", "Age_Group_50", "Age not stated"]]
census_data_relevant
# Out:
#                       State name              District Name  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Male_Literate  Female_Literate  \
# ...

# %% [markdown]
# Problem Statement 2: (Rename the Column names)

# %%
# Rename the column names
census_data_relevant = census_data_relevant.rename(columns={"State name": "State/UT", "District Name": "District", "Male_Literate": "Literate_Male", "Female_Literate": "Literate_Female","Rural_Households": "Households_Rural", "Urban_Households": "Households_Urban", "Age_Group_0_29": "Young_and_Adult", "Age_Group_30_49": "Middle_Aged", "Age_Group_50": "Senior_Citizen", "Age not stated": "Age_Not_Stated"})
census_data_relevant
# Out:
#                         State/UT                   District  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %% [markdown]
# Problem Statement 3: (Rename State/UT Names)

# %%
# Function to format state names
def format_state_name(state_name):
    return " ".join(word.title() for word in state_name.split()).replace(" And ", " and ")

# Apply the function to the State/UT column
census_data_relevant["State/UT"] = census_data_relevant["State/UT"].apply(format_state_name)
census_data_relevant.to_csv("census.csv",index=False)
census_data_relevant
# Out:
#                         State/UT                   District  Population  \
# 0              Jammu and Kashmir                    Kupwara    870354.0
# 1              Jammu and Kashmir                     Badgam    753745.0
# 2              Jammu and Kashmir                Leh(Ladakh)    133487.0
# 3              Jammu and Kashmir                     Kargil    140802.0
# 4              Jammu and Kashmir                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  Pondicherry                       Mahe     41816.0
# 636                  Pondicherry                   Karaikal    200222.0
# 637  Andaman and Nicobar Islands                   Nicobars     36842.0
# 638  Andaman and Nicobar Islands  North  AND Middle Andaman    105597.0
# 639  Andaman and Nicobar Islands              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %% [markdown]
# Problem Statement 4: (New State/UT formation)

# %%
telangana_districts_file = (r"Data\Telangana.txt")
with open(telangana_districts_file, 'r') as file:
    telangana_districts = [line.strip() for line in file]

# Update State/UT for Telangana
census_data_relevant.loc[census_data_relevant['District'].isin(telangana_districts), 'State/UT'] = 'Telangana'

# Read Ladakh districts
ladakh_districts = ["Leh","Kargil","Leh(Ladakh)"]

# Update State/UT for Ladakh
census_data_relevant.loc[census_data_relevant['District'].isin(ladakh_districts), 'State/UT'] = 'Ladakh'

# Save the updated DataFrame
census_data_relevant.to_csv("census.csv",index=False)
census_data_relevant
# Out:
#                         State/UT                   District  Population  \
# 0              Jammu and Kashmir                    Kupwara    870354.0
# 1              Jammu and Kashmir                     Badgam    753745.0
# 2                         Ladakh                Leh(Ladakh)    133487.0
# 3                         Ladakh                     Kargil    140802.0
# 4              Jammu and Kashmir                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  Pondicherry                       Mahe     41816.0
# 636                  Pondicherry                   Karaikal    200222.0
# 637  Andaman and Nicobar Islands                   Nicobars     36842.0
# 638  Andaman and Nicobar Islands  North  AND Middle Andaman    105597.0
# 639  Andaman and Nicobar Islands              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %% [markdown]
# Problem Statement 5: (Find and process Missing Data)

# %%
# Calculate percentage of missing data before filling
missing_percentage_before = pd.read_csv(r"Data\census_2011.csv").isnull().mean() * 100

# Fill missing values based on hints
census_data_relevant["Population"].fillna(census_data_relevant["Male"] + census_data_relevant["Female"], inplace=True)
census_data_relevant["Literate"].fillna(census_data_relevant["Literate_Male"] + census_data_relevant["Literate_Female"], inplace=True)
census_data_relevant["Population"].fillna(census_data_relevant["Young_and_Adult"] + census_data_relevant["Middle_Aged"] + census_data_relevant["Senior_Citizen"] + census_data_relevant["Age_Not_Stated"], inplace=True)
census_data_relevant["Households"].fillna(census_data_relevant["Households_Rural"] + census_data_relevant["Households_Urban"], inplace=True)

# Calculate percentage of missing data after filling
missing_percentage_after = census_data_relevant.isnull().mean() * 100

# Visualization
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x=missing_percentage_before.index, y=missing_percentage_before, color='red', label='Before Filling')
sns.barplot(x=missing_percentage_after.index, y=missing_percentage_after, color='green', label='After Filling')
ax.set_ylabel('Percentage of Missing Data')
ax.set_title('Comparison of Missing Data Before and After Filling')
ax.legend()
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pc872\AppData\Local\Temp\ipykernel_25524\1360820379.py:21: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# Problem Statement 6: (Save Data)

# %% [markdown]
# Extract Information from the housing data along with the census data

# %% [markdown]
# Problem Statement 7: (Process the relevant data)

# %%
# Read housing data
housing_data = pd.read_csv(r"Data\housing.csv")

# Read census data
census_data = pd.read_csv(r"Data\census_2011.csv")

housing_data
# Out:
#       State Code                 State Name  District Code  \
# 0              1            JAMMU & KASHMIR              1
# 1              1            JAMMU & KASHMIR              1
# 2              1            JAMMU & KASHMIR              1
# 3              1            JAMMU & KASHMIR              2
# 4              1            JAMMU & KASHMIR              2
# ...          ...                        ...            ...
# 1903          35  ANDAMAN & NICOBAR ISLANDS            639
# 1904          35  ANDAMAN & NICOBAR ISLANDS            639
# 1905          35  ANDAMAN & NICOBAR ISLANDS            640
# 1906          35  ANDAMAN & NICOBAR ISLANDS            640
# 1907          35  ANDAMAN & NICOBAR ISLANDS            640
#
#                 District Name  Tehsil Code              Tehsil Name  \
# 0                     Kupwara            0                  Kupwara
# 1                     Kupwara            0                  Kupwara
# ...

# %%
# Merge the housing data with census data based on District Name
merged_data = pd.merge(housing_data, census_data, on='District Name')

# Convert relevant columns to numeric data type
merged_data['Total Number of households'] = pd.to_numeric(merged_data['Total Number of households'], errors='coerce')
merged_data['Total Number of Livable'] = pd.to_numeric(merged_data['Total Number of Livable'], errors='coerce')
merged_data['Total Number of Dilapidated'] = pd.to_numeric(merged_data['Total Number of Dilapidated'], errors='coerce')
merged_data['Latrine_premise'] = pd.to_numeric(merged_data['Latrine_premise'], errors='coerce')
merged_data['Rural/Urban'] = pd.to_numeric(merged_data['Rural/Urban'], errors='coerce')

# Calculate absolute values for households and latrine premise
merged_data['Households_Rural'] = merged_data['Rural/Urban'] * merged_data['Total Number of households'] / 100
merged_data['Households_Urban'] = (100 - merged_data['Rural/Urban']) * merged_data['Total Number of households'] / 100
merged_data['Households_Rural_Livable'] = merged_data['Households_Rural'] * merged_data['Total Number of Livable'] / 100
merged_data['Households_Urban_Livable'] = merged_data['Households_Urban'] * merged_data['Total Number of Livable'] / 100
merged_data['Households_Rural_Dilapidated'] = merged_data['Households_Rural'] * merged_data['Total Number of Dilapidated'] / 100
merged_data['Households_Urban_Dilapidated'] = merged_data['Households_Urban'] * merged_data['Total Number of Dilapidated'] / 100
merged_data['Households_Rural_Toilet_Premise'] = merged_data['Households_Rural'] * merged_data['Latrine_premise'] / 100
merged_data['Households_Urban_Toilet_Premise'] = merged_data['Households_Urban'] * merged_data['Latrine_premise'] / 100

# Rename the columns
merged_data.rename(columns={'District Name': 'District'}, inplace=True)

# Save the calculated data to a new CSV file
merged_data.to_csv('Data\housing.csv', index=False)

# Report discrepancies in district data
housing_districts = set(housing_data['District Name'])
census_districts = set(census_data['District Name'])

missing_in_housing = census_districts - housing_districts
missing_in_census = housing_districts - census_districts

print("Districts missing in housing data:", missing_in_housing)
print("Districts missing in census data:", missing_in_census)
# Out:
# Districts missing in housing data: {'Dadra AND Nagar Haveli', 'Lakshadweep', 'North  AND Middle Andaman', 'PONDICHERRY', 'Lahul AND Spiti'}
# Districts missing in census data: {'Lahul & Spiti', 'Dadra & Nagar Haveli', 'LAKSHADWEEP', 'Puducherry', 'North  & Middle Andaman'}

# %% [markdown]
# Problem Statement 8: (Visualise the housing data)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Read data from CSV file
data = pd.read_csv(r"Data\housing.csv")

# %%
# Visualize Number of households for 100 people
plt.figure(figsize=(10, 6))
plt.bar(data['State Name'], data['Total Number of households'])
plt.title('Number of Households per 100 People by State')
plt.xlabel('State')
plt.ylabel('Households per 100 People')
plt.xticks(rotation=45)
plt.show()

## Problem

# %%
import seaborn as sns

# Set the style of seaborn
sns.set_style("whitegrid")

# Create a figure and axis objects
plt.figure(figsize=(10, 8))

# Plot a horizontal bar chart
sns.barplot(x='Latrine_premise', y='State Name', data=data, palette='viridis')

# Set labels and title
plt.title('Percentage of Households with Toilet(s) by State')
plt.xlabel('Percentage of Households with Toilet(s)')
plt.ylabel('State')

# Show the plot
plt.show()
# Out:
# C:\Users\pc872\AppData\Local\Temp\ipykernel_25524\1866312188.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Latrine_premise', y='State Name', data=data, palette='viridis')

# %%
# Visualize Urban to rural population ratio
plt.figure(figsize=(8, 6))
plt.scatter(data['Rural/Urban'], data['Rural/Urban'])
plt.title('Urban to Rural Population Ratio by State')
plt.xlabel('Urban Population')
plt.ylabel('Rural Population')
plt.show()



## Problem

# %%
## problem9

# %%
# Load housing data
housing_data = pd.read_csv(r"Data\housing.csv")  # Replace 'housing_data.csv' with your housing data file path
# Load census data
census_data = pd.read_csv(r"Data\census_2011.csv")  # Replace 'census_data.csv' with your census data file path

# Merge the two datasets based on a common identifier (e.g., district name)
merged_data = pd.merge(housing_data, census_data, on='District Name', suffixes=('_housing', '_census'))

# Calculate the percentage difference between "Households_Rural" and "Households_Urban"
merged_data['Difference'] = abs((merged_data['Households_Rural_housing'] - merged_data['Households_Urban_housing']) / merged_data['Households_Rural_housing']) * 100

# Identify districts with a major difference (> 10%)
districts_with_major_difference = merged_data[merged_data['Difference'] > 10]

# Report the names of districts with major differences
print("Districts with major differences (> 10%):")
print(districts_with_major_difference['District Name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25524\1654534355.py in ?()
#       3 # Load census data
#       4 census_data = pd.read_csv(r"Data\census_2011.csv")  # Replace 'census_data.csv' with your census data file path
#       5
#       6 # Merge the two datasets based on a common identifier (e.g., district name)
# ----> 7 merged_data = pd.merge(housing_data, census_data, on='District Name', suffixes=('_housing', '_census'))
#       8
#       9 # Calculate the percentage difference between "Households_Rural" and "Households_Urban"
#      10 merged_data['Difference'] = abs((merged_data['Households_Rural_housing'] - merged_data['Households_Urban_housing']) / merged_data['Households_Rural_housing']) * 100
#
# ...

# %%
## problem 10

# %%
import pandas as pd

# Read hospital data
hospital_data = pd.read_csv(r"Data\hospitals.csv")

# Read metadata to map acronyms to full names
metadata = pd.read_csv(r"Data\metadata.csv")

# Create a dictionary to map acronyms to full names
acronym_mapping = dict(zip(metadata['Acronyms'], metadata['Full Name']))

# Rename headers in hospital data
hospital_data.rename(columns=acronym_mapping, inplace=True)

# Rename the first header to 'State/UT'
hospital_data.rename(columns={hospital_data.columns[0]: 'State/UT'}, inplace=True)

# Save the modified hospital data to a new CSV file
hospital_data.to_csv('Data/hospitals_modified.csv', index=False)

# Display the first few rows of the modified hospital data
print(hospital_data.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc872\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Full Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 10
# ...

# %%
import pandas as pd

# Read hospital data
hospital_data = pd.read_csv(r"Data\hospitals.csv")

# Define the acronym mapping based on metadata
acronym_mapping = {
    'Number of Primary Health Centers(PHCs)': 'Primary Health Centers',
    'Community Health Centers(CHCs)': 'Community Health Centers',
    'Sub-District/Divisional Hospitals(SDHs)': 'Sub-District/Divisional Hospitals',
    'District Hospitals(DHs)': 'District Hospitals'
}

# Rename headers in hospital data
hospital_data.rename(columns=acronym_mapping, inplace=True)

# Rename the first header to 'State/UT'
hospital_data.rename(columns={hospital_data.columns[0]: 'State/UT'}, inplace=True)

# Specify the path to save the modified hospital data
output_file_path = r"Data\hospitals_modified.csv"

# Save the modified hospital data to a new CSV file
hospital_data.to_csv(output_file_path, index=False)

# Display the first few rows of the modified hospital data
print(hospital_data.head())
# Out:
#                     State/UT   PHC  CHC  SDH  DH Hospitals HospitalBeds
# 0  Andaman & Nicobar Islands    27    4  NaN   3        34         1246
# 1             Andhra Pradesh  1417  198   31  20      1666        60799
# 2          Arunachal Pradesh   122   62  NaN  15       199         2320
# 3                      Assam  1007  166   14  33      1220        19115
# 4                      Bihar  2007   63   33  43      2146        17796

# %%
import pandas as pd

# Function to correct State/UT names
def correct_state_ut_names(state_ut_name):
    # Manually identify and fix the differences
    corrections = {
        "UTTARANCHAL": "UTTARAKHAND",
        # Add more corrections as needed
    }
    return corrections.get(state_ut_name, state_ut_name)  # Return the corrected name, or the original name if no correction is needed

# Read hospital data
hospital_data = pd.read_csv(r"Data\hospitals_modified.csv")  # Replace "path_to_hospital_data.csv" with the actual path to your hospital data file

# Apply the correction function to State/UT names
hospital_data['State/UT'] = hospital_data['State/UT'].apply(correct_state_ut_names)

# Specify the path to save the corrected hospital data
output_file_path = r"Data\hospitals_modified.csv"

# Save the corrected hospital data to a new CSV file
hospital_data.to_csv(output_file_path, index=False)

# Display the first few rows of the corrected hospital data
print(hospital_data.head())
# Out:
#                     State/UT   PHC  CHC  SDH  DH Hospitals HospitalBeds
# 0  Andaman & Nicobar Islands    27    4  NaN   3        34         1246
# 1             Andhra Pradesh  1417  198   31  20      1666        60799
# 2          Arunachal Pradesh   122   62  NaN  15       199         2320
# 3                      Assam  1007  166   14  33      1220        19115
# 4                      Bihar  2007   63   33  43      2146        17796
